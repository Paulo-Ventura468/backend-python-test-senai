# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulo-Ventura468/backend-python-test-senai/blob/feat-contagem-caracter-001/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite um número: "))

def argumento(n):

 if n > 0:
  print("P")
  print("Seu número é positivo")
 else:
  print("N")
  print("Seu número é negativo")



argumento(n)
# Out:
# Digite um número: -2
# N
# Seu número é negativo
